# %% [markdown]
# <img src="images/seemapldbig.png">

# %% [markdown]
# # What's Our Goal With Survival Analysis Prediction
#
# <img src="images/predictor.png">
#
# # Examples:
#
# ## &emsp;Health Outcomes
#
# ### &emsp;&emsp;-&emsp;predict patient survival time by symptoms, age, genetic expression activity, ...
#
# ## &emsp;Customer Activity
#
# ### &emsp;&emsp;-&emsp;predict when customer might cancel a subscription based on their product rating, ...
#
# ## &emsp;Machine Failure
#
# ### &emsp;&emsp;-&emsp;predict part failure from its age, temperature, lot,  ...

# %% [markdown]
# # Time-To-Event Is What We Want, But Realistically...
#
# <img src="images/predictor_prob.png">

# %% [markdown]
# # Let's Now Train A Machine Learning Model Using A Typical Pipeline...

# %% [markdown]
# <img src="images/3steps.png">

# %% [markdown]
# # Work-Through Example: Predicting Cancer Deaths
#
# ### -&emsp;dataset is cancer death ddata from 2012 called METABRIC
#
# ### -&emsp;contains about 2000 patient records with ***Gene Expression*** data
#
# ### -&emsp;goal is to train an ML model that can predict survival time of patients in clinical trial
#
# ( Apologies its a morbid dataset )

# %% [markdown]
# # Let's get started ( please follow me and don't skip ahead yet! )

# %% [markdown]
# # Load The Dataset...
# <img src="images/load-data.png">

# %%
#
# Prepare this notebook by "import"ing the python packages we will need
#

# I've pre-package a bunch of high-level codee functions for the survival analysis tutorial/workshop.
# I recommend you explore the code in this python package at a later time!
import survival_analysis

print("Done.")
# Out:
# Done.

# %%
#
# Load the dataset
#

survival_data = survival_analysis.get_cancer_death_data()

print("dataset rows=", survival_data.shape[0], "columns=", survival_data.shape[1])
# Out:
# dataset rows= 1904 columns= 12

# %% [markdown]
# # Explore The Dataset...
# <img src="images/explore-data.png">

# %%
#
# Explore the data
#

dataframe = survival_data.head(20)
dataframe
# Out:
#        MKI67      EGFR        PGR     ERBB2  hormone trtmt  radiothrpy  \
# 0   5.603834  7.811392  10.797988  5.967607            1.0         1.0
# 1   5.284882  9.581043  10.204620  5.664970            1.0         0.0
# 2   5.920251  6.776564  12.431715  5.873857            0.0         1.0
# 3   6.654017  5.341846   8.646379  5.655888            0.0         0.0
# 4   5.456747  5.339741  10.555724  6.008429            1.0         0.0
# 5   5.425826  6.331182  10.455145  5.749053            1.0         1.0
# 6   5.624060  5.679635   9.819317  5.613775            1.0         1.0
# 7   5.916774  5.289600  12.981733  6.009507            0.0         1.0
# 8   5.865741  6.738176  10.850687  5.596416            0.0         0.0
# 9   7.125732  5.484323  10.498713  6.128778            0.0         0.0
# 10  6.794005  5.218476  11.451638  5.757290            1.0         1.0
# 11  6.333529  5.170259   8.742507  6.500216            0.0         1.0
# 12  6.239752  6.118778   9.936554  5.645523            1.0         0.0
# 13  5.730411  5.383985  10.523773  5.878819            0.0         1.0
# 14  5.411055  5.616082  13.753037  6.004692            0.0         1.0
# 15  6.008168  6.161963   9.692871  5.840226            1.0         1.0
# 16  5.523213  6.359176   9.907386  5.611771            0.0         0.0
# 17  7.660975  5.285067  12.966705  5.751907            0.0         1.0
# 18  5.724731  5.404722   8.765630  5.725217            0.0         1.0
# 19  6.082559  6.114430  10.301942  6.151016            0.0         0.0
#
#     chemothrpy  ER-pos        age        days  died          ID
# 0          0.0     1.0  56.840000   99.333336     0   patient_0
# 1          0.0     1.0  85.940002   95.733330     1   patient_1
# 2          0.0     1.0  48.439999  140.233337     0   patient_2
# 3          0.0     0.0  66.910004  239.300003     0   patient_3
# 4          0.0     1.0  67.849998   56.933334     1   patient_4
# 5          0.0     1.0  70.519997  123.533333     0   patient_5
# 6          0.0     1.0  49.919998  261.200012     0   patient_6
# 7          0.0     1.0  64.610001  143.000000     1   patient_7
# 8          0.0     1.0  68.209999  150.600006     1   patient_8
# 9          0.0     0.0  80.339996   49.433334     1   patient_9
# 10         1.0     0.0  64.680000   83.666664     1  patient_10
# 11         1.0     0.0  55.020000  141.166672     0  patient_11
# 12         1.0     1.0  60.619999   63.500000     1  patient_12
# 13         0.0     1.0  63.919998   52.733334     1  patient_13
# 14         0.0     1.0  42.880001   44.733334     1  patient_14
# 15         1.0     1.0  39.299999   48.599998     1  patient_15
# 16         0.0     0.0  90.430000   26.733334     1  patient_16
# 17         0.0     0.0  48.450001   51.000000     1  patient_17
# 18         0.0     1.0  76.959999   28.066668     1  patient_18
# 19         0.0     1.0  62.840000   51.966667     1  patient_19

# %% [markdown]
# # A Note About The Dataset Columns...
#
# | Factor | Type | Description |
# | --- | --- | --- |
# | MKI67  | numeric | gene expression for MKI67 |
# | EGFR  | numeric | gene expression for EGFR  |
# | PGR  | numeric | gene expression for PGR  |
# | ERBB2  | numeric | gene expression for ERBB2  |
# | hormone trtmnt  | binary | patient underwent hormone treatment |
# | radiothrpy  | binary | patient underwent radiotherapy |
# | chemothrpy  | binary | patient underwent chemotherapy  |
# | ER-pos  | binary | patient underwent ER-positive therapy |
# | age  | binary | patient age |
# | duration  | numeric | days survived |
# | event  | binary | patient died during study |
#
# ### ( Obviously, for customer churn or machine failure prediction the data and columns will be different...)

# %% [markdown]
# # Continuing the data exploration...let's get summary statistics for a few columns...

# %%
#
# Explore the "numeric columns
#

survival_data[['MKI67', 'EGFR', 'PGR', 'ERBB2', 'age', 'days']].describe()
# Out:
#              MKI67         EGFR          PGR        ERBB2          age  \
# count  1904.000000  1904.000000  1904.000000  1904.000000  1904.000000
# mean      6.210828     6.237204    10.765365     5.872816    61.087055
# std       0.862967     1.020871     1.357359     0.341254    12.978711
# min       5.158794     4.860645     6.372949     5.101093    21.930000
# 25%       5.692096     5.408728     9.969681     5.622290    51.375001
# 50%       5.949283     5.877591    10.530301     5.816998    61.769999
# 75%       6.458780     6.899220    11.159306     6.058293    70.592497
# max      14.443632     9.932116    14.643900     7.658863    96.290001
#
#               days
# count  1904.000000
# mean    125.025124
# std      76.334198
# min       0.000000
# 25%      60.824999
# 50%     114.900002
# 75%     184.474995
# max     355.200012

# %% [markdown]
# # Transform The Dataset...
# <img src="images/transform-data.png">

# %%
# Transform the dataset for our machine learning model...

train_dataset, validation_dataset, test_dataset = survival_analysis.transform_data(valid_frac=0.2, test_frac=0.2)

print("training dataset rows=", train_dataset.shape[0])

print("validation dataset rows=", validation_dataset.shape[0])

print("test dataset rows=", test_dataset.shape[0])
# Out:
# training dataset rows= 1524
# validation dataset rows= 380
# test dataset rows= 380

# %% [markdown]
# # So Why Do We Split The Original Dataset?
#
# ### -&emsp;Training Dataset: We usually keep most of it for training the model
#
# ### -&emsp;Validation Dataset: We take a portion to measure how well the training is going ( and when to stop! )
#
# ### -&emsp;Test Dataseet: We keep a "hold-out" dataset to evaluate the final model

# %% [markdown]
# <img src="images/whysplit.png">

# %% [markdown]
# # Choose A Machine Learning Model...
# <img src="images/choose_the_model.png">
#
# ( Note I chose it for the workshop...)

# %%
# We will try a small neural network here called a multi-layer perceptron.
# Let's print out the "architecture" and discuss what the layers mean...

ml_model = survival_analysis.choose_multilayer_perceptron()

##print(type(ml_model))
print("model architecture=", ml_model)

##print(dir(ml_model))
#rint(ml_model.state_dict())
#from torchviz import make_dot
#make_dot(ml_model).render("attached", format="png")
# Out:
# model architecture= MLPVanilla(
#   (net): Sequential(
#     (0): DenseVanillaBlock(
#       (linear): Linear(in_features=9, out_features=32, bias=True)
#       (activation): ReLU()
#       (batch_norm): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (1): DenseVanillaBlock(
#       (linear): Linear(in_features=32, out_features=32, bias=True)
#       (activation): ReLU()
#       (batch_norm): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (2): Linear(in_features=32, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# # Prepare To Train The Model...
#
# <img src="images/prepare-model.png">

# %%
# There are some "hyper-parameters" we will use to prepare the training.
# Let's discuss what these mean...

epochs, stop_criteria = survival_analysis.prepare_training()

print("training epochs=", epochs)
print("stop_criteria=", stop_criteria)
# Out:
# training epochs= 100
# stop_criteria= early-stopping

# %% [markdown]
# # Train The Model...
#
# <img src="images/train-model.png">

# %%
# Let's go ahead and train the model and discuss the output

trained_model = survival_analysis.train_model()
# Out:
# 0:	[0s / 0s],		train_loss: 3.0469,	val_loss: 2.8188
# 1:	[0s / 0s],		train_loss: 2.6971,	val_loss: 2.5372
# 2:	[0s / 0s],		train_loss: 2.3195,	val_loss: 2.0805
# 3:	[0s / 0s],		train_loss: 1.8775,	val_loss: 1.6652
# 4:	[0s / 0s],		train_loss: 1.5693,	val_loss: 1.5077
# 5:	[0s / 0s],		train_loss: 1.4224,	val_loss: 1.5009
# 6:	[0s / 0s],		train_loss: 1.3975,	val_loss: 1.4899
# 7:	[0s / 0s],		train_loss: 1.3667,	val_loss: 1.4540
# 8:	[0s / 0s],		train_loss: 1.3424,	val_loss: 1.4388
# 9:	[0s / 0s],		train_loss: 1.3128,	val_loss: 1.4260
# 10:	[0s / 0s],		train_loss: 1.3298,	val_loss: 1.4233
# 11:	[0s / 0s],		train_loss: 1.3043,	val_loss: 1.4207
# 12:	[0s / 0s],		train_loss: 1.3018,	val_loss: 1.4267
# 13:	[0s / 0s],		train_loss: 1.2975,	val_loss: 1.4296
# 14:	[0s / 0s],		train_loss: 1.2844,	val_loss: 1.4319
# 15:	[0s / 0s],		train_loss: 1.2771,	val_loss: 1.4381
# 16:	[0s / 0s],		train_loss: 1.2911,	val_loss: 1.4408
# 17:	[0s / 0s],		train_loss: 1.2779,	val_loss: 1.4451
# 18:	[0s / 0s],		train_loss: 1.2837,	val_loss: 1.4429
# 19:	[0s / 0s],		train_loss: 1.2760,	val_loss: 1.4476
# 20:	[0s / 0s],		train_loss: 1.2659,	val_loss: 1.4542
# 21:	[0s / 0s],		train_loss: 1.2567,	val_loss: 1.4570

# %% [markdown]
# # Evaluate The Final Model...
#
# <img src="images/eval-model.png">

# %%
# Remember, we removed some of the original data for testing our final model.
# It was not used in training the model and contains "ground truth" data - that is,
# we know how long the patient survived.  We can use it to determine how well our 
# model predicts survival.

# Let's look at some of that 'test data'...

test_dataset.iloc[0:10,:]
# Out:
#          MKI67      EGFR        PGR     ERBB2  hormone trtmt  radiothrpy  \
# 364   5.505141  8.638374  10.849506  6.638455            0.0         0.0
# 577   5.567882  5.459702  13.863100  6.231246            0.0         1.0
# 1238  5.933456  6.357396  11.204230  5.982156            0.0         0.0
# 329   5.343498  5.601614  11.148868  6.159947            1.0         1.0
# 1185  5.970478  5.847399  11.653483  5.646510            0.0         0.0
# 907   5.631753  6.977419  10.330307  5.703781            1.0         1.0
# 631   5.403924  6.140525  11.485667  5.500154            0.0         1.0
# 1000  6.758899  6.168967   9.798991  5.110848            0.0         1.0
# 912   6.085110  5.445497  11.361155  6.313169            1.0         0.0
# 1709  6.994829  5.671229   9.288567  6.408274            1.0         1.0
#
#       chemothrpy  ER-pos        age        days  died            ID
# 364          0.0     1.0  80.330002   69.099998     1   patient_364
# 577          1.0     0.0  46.759998   35.633335     1   patient_577
# 1238         0.0     1.0  50.070000  252.966660     0  patient_1238
# 329          0.0     1.0  63.430000  222.199997     0   patient_329
# 1185         0.0     1.0  81.760002  107.766670     1  patient_1185
# 907          1.0     1.0  43.389999  131.066666     0   patient_907
# 631          0.0     1.0  59.230000  263.033325     0   patient_631
# 1000         0.0     1.0  57.360001   86.900002     0  patient_1000
# 912          0.0     1.0  77.940002  151.166672     1   patient_912
# 1709         1.0     0.0  64.269997  194.100006     1  patient_1709

# %%
# Let's focus on the first two patients (patient 379 and 1711)

two_patients = test_dataset[ \
        (test_dataset['ID']=='patient_364') | (test_dataset['ID']=='patient_577') ]

two_patients
# Out:
#         MKI67      EGFR        PGR     ERBB2  hormone trtmt  radiothrpy  \
# 364  5.505141  8.638374  10.849506  6.638455            0.0         0.0
# 577  5.567882  5.459702  13.863100  6.231246            0.0         1.0
#
#      chemothrpy  ER-pos        age       days  died           ID
# 364         0.0     1.0  80.330002  69.099998     1  patient_364
# 577         1.0     0.0  46.759998  35.633335     1  patient_577

# %%
# Let's look at the predicted survival probability curve for these two patients and discuss

survival_analysis.predict( two_patients )

# %%
# We can perform this qualitative metric, called the concordance index, on the entire 
# "held-out" test set to get the overall quality of the predictive model.

model_quality = survival_analysis.predict_model_concordance_index()

print("The model quality is", model_quality, " out of 100.  You could say it can predict with that accuracy.")
# Out:
# The model quality is 69.36  out of 100.  You could say it can predict with that accuracy.

# %% [markdown]
# # Now its your turn:  go back and change the fraction of test and valid data to 0.3 each, retrain, and evaluation.  Did it change the results?

# %% [markdown]
# # Summary: Let's Review What We Learned
#
# ### &emsp;- ML Projects Are Generated Focused On Three Activites
#
# ### &emsp;- Preparing The Data
#
# ### &emsp;- Training the Model
#
# ### &emsp;- Evaluating The Model
#
# ### &emsp;- Split the Original Data To Accomodate Training And Evaluating
#
# ### &emsp;- Monitor Training To Know When To Stop

# %% [markdown]
# # More Survival Analysis Topics For Your Own Study Later
#
# ### &emsp;- Pycox Survival ML Python Package
#
# ### &emsp;- DeepSurv
#
# ### &emsp;- DeepWeibull
#
# ### &emsp;- Google's Kaggle Competition For METABRIC
